# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
#& importing file 
df1= pd.read_csv('datasets.csv')

# %%
df= df1.copy()

# %%
df
# Out:
#                  id                                               name  \
# 0      1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...             ...                                                ...
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
df.isna().any().sum()
# Out:
# np.int64(12)

# %%
df.sample(10)
# Out:
#                  id                                               name  \
# 6867   1.608521e+07  Rental unit in New York · ★4.44 · 2 bedrooms ·...
# 16845  3.156461e+07  Rental unit in Queens · ★4.69 · 1 bedroom · 1 ...
# 3841   7.160000e+17  Rental unit in Queens · ★4.64 · 1 bedroom · 2 ...
# 18445  5.218955e+07      Rental unit in Brooklyn · 1 bedroom · 2 baths
# 2986   5.253428e+07  Rental unit in New York · ★4.42 · Studio · 2 b...
# 8872   4.781474e+07  Rental unit in Queens · ★4.70 · Studio · 1 bed...
# 18270  5.780000e+17  Rental unit in Brooklyn · ★5.0 · 1 bedroom · 1...
# 13459  9.920000e+17  Hotel in New York · ★4.30 · 1 bedroom · 1 bed ...
# 418    5.138755e+07  Rental unit in Queens · ★4.92 · 1 bedroom · 1 ...
# 5373   3.963635e+06  Home in Brooklyn  · ★4.86 · 3 bedrooms · 4 bed...
#
#          host_id       host_name neighbourhood_group       neighbourhood  \
# 6867    61391963  Stay With Vibe           Manhattan            Kips Bay
# ...

# %%
df.shape
# Out:
# (20770, 22)

# %%
#! data describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %%
df['price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['price']>1000]
# Out:
#                  id                                               name  \
# 305    4.326578e+07  Boutique hotel in New York · ★4.43 · Studio · ...
# 482    8.985316e+06  Rental unit in New York · ★4.43 · 1 bedroom · ...
# 579    5.980000e+17  Rental unit in New York · 4 bedrooms · 3 beds ...
# 906    3.899368e+07  Boutique hotel in New York · 1 bedroom · 1 bed...
# 985    6.191440e+05  Rental unit in New York · 1 bedroom · 1 bed · ...
# ...             ...                                                ...
# 18501  2.798570e+05  Home in Brooklyn · ★4.87 · 8 bedrooms · 18 bed...
# 19159  2.261367e+06  Home in Brooklyn · ★4.77 · 14 bedrooms · 42 be...
# 19469  7.300000e+17  Townhouse in New York · ★5.0 · 3 bedrooms · 3 ...
# 20071  2.513789e+07  Home in Queens · ★4.90 · 3 bedrooms · 5 beds ·...
# 20687  3.100156e+07  Boutique hotel in New York · ★5.0 · 1 bedroom ...
#
#          host_id          host_name neighbourhood_group       neighbourhood  \
# ...

# %%
df[df['room_type']=='Private room']['price']
# Out:
# 0         55.0
# 3        120.0
# 8        120.0
# 13        90.0
# 15       120.0
#          ...
# 20758     65.0
# 20759     53.0
# 20762     79.0
# 20765     45.0
# 20769    102.0
# Name: price, Length: 8803, dtype: float64

# %%
df['price'].skew()
# Out:
# np.float64(89.97557856732496)

# %%
#* data cleaning
df.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      7
# latitude                           7
# longitude                          7
# room_type                          7
# price                             34
# minimum_nights                     7
# number_of_reviews                  7
# last_review                        7
# reviews_per_month                  7
# calculated_host_listings_count     7
# availability_365                   7
# number_of_reviews_ltm              7
# license                            0
# rating                             0
# bedrooms                           0
# beds                               0
# baths                              0
# dtype: int64

# %%
df[df['latitude'].isnull()]
# Out:
#                  id                                               name  \
# 15913  4.704742e+07  Guest suite in New York · ★4.88 · 8 bedrooms ·...
# 15914  3.890630e+07  Loft in Brooklyn · ★4.71 · 1 bedroom · 1 bed ·...
# 15915  4.678660e+05  Rental unit in New York · ★4.90 · 1 bedroom · ...
# 15916  3.303301e+06  Loft in Brooklyn · ★4.89 · 1 bedroom · 1 bed ·...
# 15917  1.661685e+07  Rental unit in Brooklyn · ★4.81 · 1 bedroom · ...
# 15918  7.940000e+17  Rental unit in Brooklyn · ★4.80 · 2 bedrooms ·...
# 15919  4.810402e+07  Rental unit in New York · ★4.50 · Studio · 2 b...
#
#          host_id  host_name neighbourhood_group neighbourhood  latitude  \
# 15913  380290574      Karen           Manhattan           NaN       NaN
# 15914   51954926          K            Brooklyn           NaN       NaN
# 15915    2321870      David           Manhattan           NaN       NaN
# 15916   12385603       Anne            Brooklyn           NaN       NaN
# ...

# %% [markdown]
# # drop the null values

# %%
df.dropna(subset=['latitude','last_review','minimum_nights','longitude','price'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
df.shape
# Out:
# (20736, 22)

# %%
#! dealing with duplicated records
df[df.duplicated()]

#* delete thee duplicate value
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#! chage price to float to int
df['price'] =df['price'].astype('int')

# %%
#* changing the id and host id type of now
df['host_id']= df['host_id'].astype('int')
df['id']= df['id'].astype('int')

# %%
#! date time 
df['last_review']=pd.to_datetime(df['last_review'])

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
df.shape
# Out:
# (20724, 22)

# %% [markdown]
# # Univariate analysis

# %%
df['price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['price'].skew()
# Out:
# np.float64(89.9500076528325)

# %%
df[df['price']>50000]
# Out:
#                       id                                               name  \
# 3995            17160286  Rental unit in Brooklyn · ★4.48 · 1 bedroom · ...
# 5497  605000000000000000  Rental unit in Brooklyn · ★4.33 · 1 bedroom · ...
#
#         host_id host_name neighbourhood_group       neighbourhood  latitude  \
# 3995  110361431     Bobbi            Brooklyn  Bedford-Stuyvesant  40.69085
# 5497  110361431     Bobbi            Brooklyn  Bedford-Stuyvesant  40.69254
#
#       longitude     room_type   price  ...  last_review  reviews_per_month  \
# 3995  -73.93806  Private room  100000  ...   2023-10-20               0.96
# 5497  -73.93636  Private room  100000  ...   2023-10-31               0.45
#
#      calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 3995                            2.0             346.0                   10.0
# 5497                            2.0             365.0                    5.0
#
# ...

# %%
df['price'].plot(kind='hist')
sns.kdeplot(data=df,x='price',hue='neighbourhood_group')
# Out:
# <Axes: xlabel='price', ylabel='Frequency'>

# %%
df[df['price']>10000]
# Out:
#                       id                                               name  \
# 3995            17160286  Rental unit in Brooklyn · ★4.48 · 1 bedroom · ...
# 5497  605000000000000000  Rental unit in Brooklyn · ★4.33 · 1 bedroom · ...
#
#         host_id host_name neighbourhood_group       neighbourhood  latitude  \
# 3995  110361431     Bobbi            Brooklyn  Bedford-Stuyvesant  40.69085
# 5497  110361431     Bobbi            Brooklyn  Bedford-Stuyvesant  40.69254
#
#       longitude     room_type   price  ...  last_review  reviews_per_month  \
# 3995  -73.93806  Private room  100000  ...   2023-10-20               0.96
# 5497  -73.93636  Private room  100000  ...   2023-10-31               0.45
#
#      calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 3995                            2.0             346.0                   10.0
# 5497                            2.0             365.0                    5.0
#
# ...

# %%
#* price analyis
# d =df[df['price']>15000].dropna(inplace=True)

# %%
#! identyfing outliers in price
df=df[df['price']<1200]

# %%
df.shape
# Out:
# (20590, 22)

# %%
df['price'].sample(10)
# Out:
# 128       80
# 9272     105
# 4806     139
# 3732      77
# 20526    193
# 12586    101
# 15624    258
# 13517    700
# 20017    196
# 11620     55
# Name: price, dtype: int64

# %%
df['price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['price'].skew()
# Out:
# np.float64(2.9071885092018275)

# %% [markdown]
# Removing outlier using uppper limit one new thing

# %%
#! removing outliers
upper_limit = df['price'].quantile(0.98)

df= df[df['price'] <=upper_limit]

# %%
df['price'].skew()
# Out:
# np.float64(1.6385074790875476)

# %%
df['price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
sns.histplot(data=df ,x='price',hue='neighbourhood_group',kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='price',hue='room_type')
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
#! minimum night 
df['availability_365'].plot(kind='hist',edgecolor='black',color='skyblue')
plt.xlabel('availability _365')
# Out:
# Text(0.5, 0, 'availability _365')

# %%
df['room_type'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['minimum_nights'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %% [markdown]
# # bivariate analyisis

# %%
#! neighbour hood and price group by to annalyized

df.groupby('neighbourhood_group')['price'].mean().plot(kind='bar',color="#0911F9",edgecolor='#070A13',figsize=(5,5),alpha=0.7)
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# # per bed Feature Engineerging

# %%
df['per_bed']= df['price']/df['beds']

# %%
df.groupby('neighbourhood_group')['per_bed'].mean().reset_index()
# Out:
#   neighbourhood_group     per_bed
# 0               Bronx   73.736568
# 1            Brooklyn   96.766033
# 2           Manhattan  127.730956
# 3              Queens   75.712101
# 4       Staten Island   67.271991

# %%
df.groupby('neighbourhood_group')['per_bed'].mean().plot(kind='bar',color="#E11530",edgecolor='black')
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# # bivariate analysis

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'per_bed'],
#       dtype='object')

# %%
sns.barplot(data=df,x='neighbourhood_group',y='price',errorbar=None,estimator=np.mean,hue='neighbourhood_group',palette='Set1')
plt.title("average price by neighbourhood group",fontsize='15',weight='light')
plt.xlabel("neighbourhood_group")
plt.ylabel('price')
plt.show()

# %%
sns.barplot(data=df,x='neighbourhood_group',y='price',errorbar=None,estimator=np.mean,hue='room_type',palette='Set1')
plt.title("average price by neighbourhood group",fontsize='15',weight='light')
plt.xlabel("neighbourhood_group")
plt.ylabel('price')
plt.show()

# %%
sns.barplot(data=df,x='room_type',y='price',errorbar=None,estimator=np.mean,hue='neighbourhood_group',palette='Set1')
plt.title("average price by neighbourhood group",fontsize='15',weight='light')
plt.xlabel("neighbourhood_group")
plt.ylabel('price')
plt.show()

# %%
sns.scatterplot(data=df,y='price',x='number_of_reviews',hue='neighbourhood_group')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %%
df['year']= df['last_review'].dt.year

# %%
#! line plot trend over year like avg price per year

avg_price= df.groupby('year')['price'].mean().reset_index()
sns.lineplot(data=avg_price,x='year',y='price',palette='Set3')
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
df.groupby('room_type')['price'].mean()
# Out:
# room_type
# Entire home/apt    188.521055
# Hotel room         239.564356
# Private room       101.628663
# Shared room         98.582456
# Name: price, dtype: float64

# %%
df.groupby('room_type')['price'].mean().plot(kind='bar',color='green',alpha=0.8,edgecolor='black')
# Out:
# <Axes: xlabel='room_type'>

# %%
# sns.pairplot(data=df,hue='neighbourhood_group')

# %% [markdown]
# # Multivariate analaysis

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
sns.pairplot(data=df,vars=['price','minimum_nights','number_of_reviews','availability_365'],hue='room_type')
plt.figure(figsize=(10,10))

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'per_bed', 'year'],
#       dtype='object')

# %%
#* geographical distrubutation of airbnb listing
plt.figure(figsize=(10,10))
sns.scatterplot(data=df,x='longitude',y='latitude',hue='room_type')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df,x='longitude',y='latitude',hue='neighbourhood_group',size='price')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.histplot(data=df,x='price',y='room_type')
# Out:
# <Axes: xlabel='price', ylabel='room_type'>

# %%
sns.displot(data=df,x='last_review',y='price',kind='kde')

# %% [markdown]
# heatmap

# %%
corr=df[['latitude','longitude','price','minimum_nights','availability_365','per_bed','number_of_reviews','reviews_per_month']].corr()

# %%
sns.heatmap(data=corr,annot=True,linewidths=0.1)
# Out:
# <Axes: >

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
heat =df.pivot_table(index='neighbourhood_group',columns='room_type',values='price')

# %%
sns.heatmap(data=heat,annot=True,linewidths=0.1)
# Out:
# <Axes: xlabel='room_type', ylabel='neighbourhood_group'>

# %%
sns.scatterplot(data=df[df['price']<1000], x='longitude', y='latitude',
                hue='neighbourhood_group', alpha=0.5)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971000000000000000  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20765            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  783000000000000000  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  566000000000000000  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
# ...

# %%
df.to_csv('report.csv',index=False)
