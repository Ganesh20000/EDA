# %% [markdown]
# # session 28

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re

# %% [markdown]
# 1)assessing data
# 2)cleaning data
# 3)explotary data
# 4)drawing conclusion
# 5)communication

# %%
pati= pd.read_csv('patients.csv')
ad=pd.read_csv('adverse_reactions.csv')
cut=pd.read_csv('treatments_cut.csv')
treat= pd.read_csv('treatments.csv')

# %% [markdown]
# write summary for your dataset

# %% [markdown]
# # writing issue with dataset

# %% [markdown]
# dity data is here

# %% [markdown]
# # Dirty data

# %%
pati
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
# dirty data with manual assement


# patient
# 1) pati_id 9   name of dsvid name is incorrect   "accuracy "

#2)state have issue with some have full name while some short 'consistency'

#3) zip code some have 4 digit 'validity'
# 4) data missing address city  state zip contact 12 values 'completion '

#5) zip code in float should int

#6) incorrect data type assigned to sex,zip ,birthcode 'validtiy
# birthday in date format should 


# jonh doe duplicated entries ' acurracy'
# five given and surname in duplicated


#  one patient has 48 pound' accuracy'
#----------------------------------------------------------------------------------------------------

# table Treat & Treatment_cut have

# have given name and surnaem have small letter all 'consistency' 

#auralin , novodra col should be split into 2 column start and end 'validy'

#remove u from auralin and novodra 

# - in novodra remove this 

# mising value in hba1c change column
 
#----------------------------------------------------------------------------------------------------

# table three 3 

#clinical trials

# name and surname in lowercase

#----------------------------------------------------------------------------------------------------

# adverse reaction

#this table should not exist indepenty

# %% [markdown]
# # messy data

# %%
# patient 
# contact and phone no in same column

#----------------------------------------------------------------------------------------------------

# %%
pati
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
sns.pairplot(pati,hue='assigned_sex')

# %%
pati.sample(10)
# Out:
#      patient_id assigned_sex  given_name      surname  \
# 76           77       female      Maryam     Dratchev
# 72           73         male       Søren  Frederiksen
# 361         362         male  Hans Peter     Radislav
# 231         232       female    Stefanie       Herman
# 466         467       female      Andrea      Brodahl
# 415         416       female      Mgbeke      Ekwueme
# 252         253         male        Juan        Pérez
# 149         150         male  Wawrzyniec   Nowakowski
# 75           76         male         Leo      Mancini
# 263         264       female       Julia     Carvalho
#
#                         address           city       state  zip_code  \
# 76            3314 Rocket Drive    Minneapolis          MN   55410.0
# 72             4852 Rose Avenue       Metairie          LA   70001.0
# 361           208 Birch  Street        El Paso          TX   79905.0
# 231           204 Rockwell Lane        Halifax          NC   27839.0
# ...

# %%
pati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %% [markdown]
# data is missing for 12 rows in this 5 columns city state zip_code country contact

# %%
pati[pati['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %% [markdown]
# duplicated

# %%
pati.duplicated().sum()
# Out:
# np.int64(0)

# %%
pati['patient_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
pati.duplicated(subset=['given_name','surname']).sum()
# Out:
# np.int64(5)

# %%
pati[pati.duplicated(subset=['given_name','surname'])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
cut.duplicated().sum()
# Out:
# np.int64(0)

# %%
treat.duplicated().sum()
# Out:
# np.int64(1)

# %%
treat[treat.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %% [markdown]
# duplicated name and surname check

# %%
treat[treat.duplicated(subset=['given_name','surname'])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
cut[cut.duplicated(subset=['given_name','surname'])]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
ad.duplicated().sum()
# Out:
# np.int64(0)

# %%
pati.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
treat.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
cut.sort_values('hba1c_start',na_position='first')
# Out:
#      given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 23     miłosław    wiśniewski          -  34u - 33u         7.51       7.08
# 19          noe        aranda  26u - 34u          -         7.51       7.17
# 58  christopher      woodward          -  55u - 51u         7.51       7.06
# 6          sara         miles  30u - 35u          -         7.53       7.12
# 47       regolo         nucci  51u - 59u          -         7.53       7.02
# ..          ...           ...        ...        ...          ...        ...
# 11     gabriela  michalčíková  26u - 36u          -         8.37       7.97
# 37        sofia     hermansen          -  34u - 34u         8.90       8.57
# 64        lixue         hsueh          -  22u - 23u         9.21       8.80
# 42        daimy         tromp          -  40u - 45u         9.41       8.94
# 39       maryam      dratchev  37u - 45u          -         9.91       9.46
#
#     hba1c_change
# 23          0.93
# 19          0.34
# ...

# %% [markdown]
# start - end = wrong calculation is wrong

# %% [markdown]
# data quality dimension

# %%
# completness
#validity
#accuracy
#consistency
#

# %% [markdown]
# order of severity

# %%
#completenss >validtiy>accuracy>consistency

# %% [markdown]
# # data cleaning

# %%
# define
# replace all missing pati_df with No Data

# subtract h1bac start and h1bac end to get all h1bac change column

# %%
pati_df =pati.copy()
treat_Df= treat.copy()
cut_df= cut.copy()
ad_df=ad.copy()

# %%
pati['address'].isnull().sum()
# Out:
# np.int64(12)

# %%
pati[pati['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %% [markdown]
# filling in copy one as no data is availeble

# %%
pati_df.fillna('NO data',inplace=True)
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_8896\1439391166.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NO data' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pati_df.fillna('NO data',inplace=True)

# %%
pati_df[pati_df['address'].isnull()]
# Out:
# Empty DataFrame
# Columns: [patient_id, assigned_sex, given_name, surname, address, city, state, zip_code, country, contact, birthdate, weight, height, bmi]
# Index: []

# %%
treat_Df['hba1c_change']=treat_Df['hba1c_start']-treat_Df['hba1c_end']

# %%
treat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
treat_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  280 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
pati
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
from io import StringIO
df = pd.read_csv(StringIO('pati_df'))

# %% [markdown]
# Contact and email and phone sepate with two new column

# %% [markdown]
# auralin and novodra merge them

# %%
treatment_df =pd.concat([treat_Df,cut_df])

# %%
treatment_df
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0    veronika    jindrová  41u - 48u          -         7.63       7.20
# 1      elliot  richardson          -  40u - 45u         7.56       7.09
# 2    yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3        skye  gormanston  33u - 36u          -         7.97       7.62
# 4      alissa      montez          -  33u - 29u         7.78       7.46
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.43
# 1           0.47
# 2           0.43
# 3           0.35
# ...

# %%
# treatment_df=treatment_df.melt(['given_name','surname','hba1c_start','hba1c_end','hba1c_change'])

# %%
treatment_df=treatment_df.melt(['given_name','surname','hba1c_start','hba1c_end','hba1c_change'],var_name='type',value_name='dosage')

# %%
treatment_df
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0     veronika    jindrová         7.63       7.20          0.43  auralin
# 1       elliot  richardson         7.56       7.09          0.47  auralin
# 2     yukitaka    takenaka         7.68       7.25          0.43  auralin
# 3         skye  gormanston         7.97       7.62          0.35  auralin
# 4       alissa      montez         7.78       7.46          0.32  auralin
# ..         ...         ...          ...        ...           ...      ...
# 695     rovzan     kishiev         7.75       7.41          0.34  novodra
# 696      jakob    jakobsen         7.96       7.51          0.95  novodra
# 697      bernd   schneider         7.74       7.44          0.30  novodra
# 698      berta  napolitani         7.68       7.21           NaN  novodra
# 699     armina       sauvé         7.86       7.40           NaN  novodra
#
#         dosage
# 0    41u - 48u
# 1            -
# 2            -
# ...

# %%
treatment_df[['type','dosage']].sample(10)
# Out:
#         type     dosage
# 539  novodra          -
# 658  novodra  35u - 34u
# 578  novodra          -
# 624  novodra          -
# 311  auralin  27u - 37u
# 25   auralin          -
# 545  novodra          -
# 3    auralin  33u - 36u
# 314  auralin          -
# 508  novodra  41u - 44u

# %% [markdown]
# # start end end spliting using -

# %%
treatment_df=treatment_df[treatment_df['dosage']  != '-']

# %%
treatment_df
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#         dosage
# 0    41u - 48u
# 3    33u - 36u
# ...

# %% [markdown]
#  start and end splint and get index

# %%
treatment_df['start']=treatment_df['dosage'].str.split('-').str.get(0)
treatment_df['end']=treatment_df['dosage'].str.split('-').str.get(1)
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_8896\4164843212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_df['start']=treatment_df['dosage'].str.split('-').str.get(0)
# C:\Users\karli\AppData\Local\Temp\ipykernel_8896\4164843212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_df['end']=treatment_df['dosage'].str.split('-').str.get(1)

# %%
treatment_df
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#         dosage start   end
# 0    41u - 48u  41u    48u
# ...

# %% [markdown]
# now remove dosage

# %%
# treatment_df.drop(columns='dosage',inplace=True)

# %%
treatment_df
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#         dosage start   end
# 0    41u - 48u  41u    48u
# ...

# %% [markdown]
# now removing u from starting and ending

# %%
treatment_df['start']=treatment_df['start'].str.replace('u','')
treatment_df['end']=treatment_df['end'].str.replace('u','')
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_8896\2519438809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_df['start']=treatment_df['start'].str.replace('u','')
# C:\Users\karli\AppData\Local\Temp\ipykernel_8896\2519438809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_df['end']=treatment_df['end'].str.replace('u','')

# %%
treatment_df['start']
# Out:
# 0      41
# 3      33
# 6      37
# 7      31
# 9      30
#       ...
# 688    55
# 690    26
# 694    22
# 696    28
# 698    42
# Name: start, Length: 350, dtype: object

# %%
treatment_df['end']
# Out:
# 0       48
# 3       36
# 6       42
# 7       38
# 9       36
#       ...
# 688     51
# 690     23
# 694     23
# 696     26
# 698     44
# Name: end, Length: 350, dtype: object

# %%
treatment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  322 non-null    float64
#  5   type          350 non-null    object
#  6   dosage        350 non-null    object
#  7   start         350 non-null    object
#  8   end           350 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 27.3+ KB

# %%
treatment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  322 non-null    float64
#  5   type          350 non-null    object
#  6   dosage        350 non-null    object
#  7   start         350 non-null    object
#  8   end           350 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 27.3+ KB

# %% [markdown]
# now merging adverse reaction to treatment _df

# %% [markdown]
# merging best result will be left

# %%
treatment_df.merge(ad,how='left',on=['given_name','surname'])
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 1           skye  gormanston         7.97       7.62          0.35  auralin
# 2         sophia      haugen         7.65       7.27          0.38  auralin
# 3          eddie      archer         7.89       7.55          0.34  auralin
# 4           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 345  christopher    woodward         7.51       7.06          0.95  novodra
# 346        maret    sultygov         7.67       7.30           NaN  novodra
# 347        lixue       hsueh         9.21       8.80          0.91  novodra
# 348        jakob    jakobsen         7.96       7.51          0.95  novodra
# 349        berta  napolitani         7.68       7.21           NaN  novodra
#
#         dosage start  end           adverse_reaction
# ...

# %%
treatment_df.merge(ad)
# Out:
#      given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0        joseph         day         7.70       7.19          0.51  auralin
# 1       clinton      miller         7.79       7.40          0.39  auralin
# 2        louise     johnson         7.63       7.32          0.31  auralin
# 3        finley    chandler         7.65       7.26          0.39  auralin
# 4        idalia       moore         8.34       7.90          0.44  auralin
# 5        xiuxiu       chang         7.64       7.23          0.41  auralin
# 6        joseph         day         7.70       7.19          0.51  auralin
# 7      gabriele     saenger         8.35       7.97          0.38  auralin
# 8         merci      leroux         8.98       8.64          0.34  auralin
# 9      anenechi       chidi         7.64       7.31          0.33  auralin
# 10      manouck     wubbels         7.66       7.40          0.26  auralin
# ...

# %%
treat_Df.plot(kind='scatter',x='hba1c_start',y='hba1c_end',s='hba1c_change')
# Out:
# <Axes: xlabel='hba1c_start', ylabel='hba1c_end'>
